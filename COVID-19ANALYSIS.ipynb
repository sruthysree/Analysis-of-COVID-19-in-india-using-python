# %% [markdown]
# # COVID-19 ANALYSIS OF INDIA USING PYTHON

# %% [markdown]
#  ## Introduction

# %%
 Covid 19 is an infectious disease caused by a  newly discovered corona virus.The data 
showing the covid cases of india in different states from january 2020 to august 2020.
In india,first covid case is reported in kerala in january 2020.The number of confirmed 
cases and number of deaths are increasing day by day in india.

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Read the File

# %%
df=pd.read_csv("C:/Users/sruthy/Desktop/covid19india.csv")

# %% [markdown]
# ## View the data

# %%
df
# Out:
#             Date Name of State / UT  Latitude  Longitude  \
# 0     30-01-2020             Kerala   10.8505    76.2711
# 1     31-01-2020             Kerala   10.8505    76.2711
# 2     01-02-2020             Kerala   10.8505    76.2711
# 3     02-02-2020             Kerala   10.8505    76.2711
# 4     03-02-2020             Kerala   10.8505    76.2711
# ...          ...                ...       ...        ...
# 4687  06-08-2020          Telangana   18.1124    79.0193
# 4688  06-08-2020            Tripura   23.9408    91.9882
# 4689  06-08-2020      Uttar Pradesh   26.8467    80.9462
# 4690  06-08-2020        Uttarakhand   30.0668    79.0193
# 4691  06-08-2020        West Bengal   22.9868    87.8550
#
#       Total Confirmed cases  Cured/Discharged/Migrated  New cases  \
# 0                         1                          0          0
# 1                         1                          0          0
# 2                         2                          0          1
# ...

# %% [markdown]
# ## view the first 10 records

# %%
df.head(10)
# Out:
#          Date Name of State / UT  Latitude  Longitude  Total Confirmed cases  \
# 0  30-01-2020             Kerala   10.8505    76.2711                      1
# 1  31-01-2020             Kerala   10.8505    76.2711                      1
# 2  01-02-2020             Kerala   10.8505    76.2711                      2
# 3  02-02-2020             Kerala   10.8505    76.2711                      3
# 4  03-02-2020             Kerala   10.8505    76.2711                      3
# 5  04-02-2020             Kerala   10.8505    76.2711                      3
# 6  05-02-2020             Kerala   10.8505    76.2711                      3
# 7  06-02-2020             Kerala   10.8505    76.2711                      3
# 8  07-02-2020             Kerala   10.8505    76.2711                      3
# 9  08-02-2020             Kerala   10.8505    76.2711                      3
#
#    Cured/Discharged/Migrated  New cases  Death cases  New recovered
# ...

# %% [markdown]
# ## view the last 10 records

# %%
df.tail(10)
# Out:
#             Date Name of State / UT  Latitude  Longitude  \
# 4682  06-08-2020         Puducherry   11.9416    79.8083
# 4683  06-08-2020             Punjab   31.1471    75.3412
# 4684  06-08-2020          Rajasthan   27.0238    74.2179
# 4685  06-08-2020             Sikkim   27.5330    88.5122
# 4686  06-08-2020         Tamil Nadu   11.1271    78.6569
# 4687  06-08-2020          Telangana   18.1124    79.0193
# 4688  06-08-2020            Tripura   23.9408    91.9882
# 4689  06-08-2020      Uttar Pradesh   26.8467    80.9462
# 4690  06-08-2020        Uttarakhand   30.0668    79.0193
# 4691  06-08-2020        West Bengal   22.9868    87.8550
#
#       Total Confirmed cases  Cured/Discharged/Migrated  New cases  \
# 4682                   4433                       2668        286
# 4683                  19856                      12943        841
# 4684                  47272                      33849        593
# 4685                    800                        303         17
# ...

# %% [markdown]
# ## to view any random records

# %%
df.sample(5)
# Out:
#             Date Name of State / UT  Latitude  Longitude  \
# 2288  26-05-2020              Assam   26.2006    92.9376
# 3660  08-07-2020            Gujarat   22.2587    71.1924
# 4604  04-08-2020             Ladakh   34.2996    78.2932
# 4411  29-07-2020        West Bengal   22.9868    87.8550
# 3466  29-06-2020             Punjab   31.1471    75.3412
#
#       Total Confirmed cases  Cured/Discharged/Migrated  New cases  \
# 2288                    526                         62        148
# 3660                  37550                      26720        778
# 4604                   1485                       1109         19
# 4411                  62964                      42022       2134
# 3466                   5216                       3526        160
#
#       Death cases  New recovered
# 2288            4              7
# 3660         1977            405
# 4604            7              1
# 4411         1449           2105
# 3466          133            206

# %% [markdown]
# ## to check the dimension of data

# %%
df.ndim
# Out:
# 2

# %% [markdown]
# ## to check how many rows and columns

# %%
df.shape
# Out:
# (4692, 9)

# %% [markdown]
# ## to check the datatypes of columns

# %%
df.dtypes
# Out:
# Date                          object
# Name of State / UT            object
# Latitude                     float64
# Longitude                    float64
# Total Confirmed cases          int64
# Cured/Discharged/Migrated      int64
# New cases                      int64
# Death cases                    int64
# New recovered                  int64
# dtype: object

# %% [markdown]
# ## show the column names

# %%
df.columns
# Out:
# Index(['Date', 'Name of State / UT', 'Latitude', 'Longitude',
#        'Total Confirmed cases', 'Cured/Discharged/Migrated', 'New cases',
#        'Death cases', 'New recovered'],
#       dtype='object')

# %% [markdown]
# ## Information about the Dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4692 entries, 0 to 4691
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       4692 non-null   object
#  1   Name of State / UT         4692 non-null   object
#  2   Latitude                   4692 non-null   float64
#  3   Longitude                  4692 non-null   float64
#  4   Total Confirmed cases      4692 non-null   int64
#  5   Cured/Discharged/Migrated  4692 non-null   int64
#  6   New cases                  4692 non-null   int64
#  7   Death cases                4692 non-null   int64
#  8   New recovered              4692 non-null   int64
# dtypes: float64(2), int64(5), object(2)
# memory usage: 330.0+ KB

# %% [markdown]
# ## Check the null values in the dataset

# %%
df.isnull().sum()
# Out:
# Date                         0
# Name of State / UT           0
# Latitude                     0
# Longitude                    0
# Total Confirmed cases        0
# Cured/Discharged/Migrated    0
# New cases                    0
# Death cases                  0
# New recovered                0
# dtype: int64

# %% [markdown]
# ## Statistical Information about the Dataset.

# %%
df.describe()
# Out:
#           Latitude    Longitude  Total Confirmed cases  \
# count  4692.000000  4692.000000            4692.000000
# mean     23.185327    81.451837           11393.925192
# std       6.635913     6.959475           37208.600846
# min       0.000000     0.000000               1.000000
# 25%      18.112400    76.271100              39.000000
# 50%      23.940800    79.019300             619.000000
# 75%      28.218000    85.313100            5233.000000
# max      34.299600    94.727800          468265.000000
#
#        Cured/Discharged/Migrated     New cases   Death cases  New recovered
# count                4692.000000   4692.000000   4692.000000    4692.000000
# mean                 6908.130648    418.643009    291.218670     283.069054
# std                 23390.671258   1259.748923   1213.695272     947.925811
# min                     0.000000      0.000000      0.000000      -1.000000
# 25%                     9.000000      1.000000      0.000000       0.000000
# ...

# %% [markdown]
# ## Variance of the Dataset.

# %%
df.var()
# Out:
# Latitude                     4.403535e+01
# Longitude                    4.843429e+01
# Total Confirmed cases        1.384480e+09
# Cured/Discharged/Migrated    5.471235e+08
# New cases                    1.586967e+06
# Death cases                  1.473056e+06
# New recovered                8.985633e+05
# dtype: float64

# %% [markdown]
# ## Correlation of Dataset

# %%
df.corr()
# Out:
#                            Latitude  Longitude  Total Confirmed cases  \
# Latitude                   1.000000   0.033416              -0.119710
# Longitude                  0.033416   1.000000              -0.157512
# Total Confirmed cases     -0.119710  -0.157512               1.000000
# Cured/Discharged/Migrated -0.102152  -0.149704               0.983722
# New cases                 -0.155901  -0.135054               0.859998
# Death cases               -0.070736  -0.164061               0.934949
# New recovered             -0.132293  -0.123183               0.879001
#
#                            Cured/Discharged/Migrated  New cases  Death cases  \
# Latitude                                   -0.102152  -0.155901    -0.070736
# Longitude                                  -0.149704  -0.135054    -0.164061
# Total Confirmed cases                       0.983722   0.859998     0.934949
# Cured/Discharged/Migrated                   1.000000   0.802218     0.900813
# ...

# %% [markdown]
# ## Covariance of Dataset.

# %%
df.corr()
# Out:
#                            Latitude  Longitude  Total Confirmed cases  \
# Latitude                   1.000000   0.033416              -0.119710
# Longitude                  0.033416   1.000000              -0.157512
# Total Confirmed cases     -0.119710  -0.157512               1.000000
# Cured/Discharged/Migrated -0.102152  -0.149704               0.983722
# New cases                 -0.155901  -0.135054               0.859998
# Death cases               -0.070736  -0.164061               0.934949
# New recovered             -0.132293  -0.123183               0.879001
#
#                            Cured/Discharged/Migrated  New cases  Death cases  \
# Latitude                                   -0.102152  -0.155901    -0.070736
# Longitude                                  -0.149704  -0.135054    -0.164061
# Total Confirmed cases                       0.983722   0.859998     0.934949
# Cured/Discharged/Migrated                   1.000000   0.802218     0.900813
# ...

# %% [markdown]
# ## State having maximum number of covid cases

# %%
df[df["Total Confirmed cases"]==df["Total Confirmed cases"].max()]
# Out:
#             Date Name of State / UT  Latitude  Longitude  \
# 4676  06-08-2020        Maharashtra   19.7515    75.7139
#
#       Total Confirmed cases  Cured/Discharged/Migrated  New cases  \
# 4676                 468265                     305521      10309
#
#       Death cases  New recovered
# 4676        16476           6165

# %% [markdown]
# ## State having maximum number of cured cases

# %%
df[df["Cured/Discharged/Migrated"]==df["Cured/Discharged/Migrated"].max()]
# Out:
#             Date Name of State / UT  Latitude  Longitude  \
# 4676  06-08-2020        Maharashtra   19.7515    75.7139
#
#       Total Confirmed cases  Cured/Discharged/Migrated  New cases  \
# 4676                 468265                     305521      10309
#
#       Death cases  New recovered
# 4676        16476           6165

# %% [markdown]
# ## State having maximum number of new covid cases

# %%
df[df["New cases"]==df["New cases"].max()]
# Out:
#             Date Name of State / UT  Latitude  Longitude  \
# 4307  26-07-2020        West Bengal   22.9868     87.855
#
#       Total Confirmed cases  Cured/Discharged/Migrated  New cases  \
# 4307                  56377                      35654      18366
#
#       Death cases  New recovered
# 4307         1332          13401

# %% [markdown]
# ## State having highest death cases

# %%
df[df["Death cases"]==df["Death cases"].max()]
# Out:
#             Date Name of State / UT  Latitude  Longitude  \
# 4676  06-08-2020        Maharashtra   19.7515    75.7139
#
#       Total Confirmed cases  Cured/Discharged/Migrated  New cases  \
# 4676                 468265                     305521      10309
#
#       Death cases  New recovered
# 4676        16476           6165

# %% [markdown]
# ## State having highest recovered cases

# %%
df[df["New recovered"]==df["New recovered"].max()]
# Out:
#             Date Name of State / UT  Latitude  Longitude  \
# 4307  26-07-2020        West Bengal   22.9868     87.855
#
#       Total Confirmed cases  Cured/Discharged/Migrated  New cases  \
# 4307                  56377                      35654      18366
#
#       Death cases  New recovered
# 4307         1332          13401

# %% [markdown]
# ## Distribution Graph of Confirmed Cases

# %%
plt.figure(figsize=(9,6))
sns.distplot(df["Total Confirmed cases"])
plt.show()

# %% [markdown]
# ## Distribution Graph of recovery Cases

# %%
plt.figure(figsize=(7,6))
sns.distplot(df["Cured/Discharged/Migrated"])
plt.show()

# %% [markdown]
# ## Distribution Graph of death Cases

# %%
plt.figure(figsize=(8,6))
sns.distplot(df["Death cases"])
plt.show()

# %% [markdown]
# ## Scatterplot of Confirmed and Death Cases

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(y=df["Total Confirmed cases"],x=df["Death cases"])
plt.title("Confirmed  cases v/s Death cases",size=16)
plt.ylabel("Total Confirmed cases",size=14)
plt.xlabel("Death cases",size=14)
plt.show()

# %% [markdown]
# ## Pairplot of Covid Cases

# %%
sns.pairplot(df)

# %% [markdown]
# ## Regression Plot of Confirmed and Death Cases

# %%
plt.figure(figsize=(8,6))
sns.regplot(y=df["Total Confirmed cases"],x=df["Death cases"])
plt.title("Regression Plot",size=15)
plt.ylabel("confirmed cases",size=14)
plt.xlabel("death cases",size=19)
plt.show()

# %% [markdown]
# ## Heat Map Shows the relationships of Covid Cases¶

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
x=df.iloc[:,-3:-2].values
y=df.iloc[:,5].values

# %%
x
# Out:
# array([[   0],
#        [   0],
#        [   1],
#        ...,
#        [4078],
#        [ 246],
#        [2816]], dtype=int64)

# %%
y
# Out:
# array([    0,     0,     0, ..., 60558,  5233, 58962], dtype=int64)

# %% [markdown]
# ## Performimg the T-Test

# %% [markdown]
# ### Train-Test-Split Evaluation

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1,random_state=0)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (4222, 1)
# (470, 1)
# (4222,)
# (470,)

# %%
print(np.mean(x_train))
print(np.mean(x_test))
print(np.mean(y_train))
print(np.mean(y_test))
# Out:
# 421.04026527711983
# 397.1085106382979
# 6950.153955471341
# 6530.636170212766

# %%
l=LinearRegression()
l.fit(x_train,y_train)
print("train test complete")
# Out:
# train test complete

# %%
y_pred=l.predict(x_test)

# %%
print("Mean Absolute Error",mean_absolute_error(y_test,y_pred))
# Out:
# Mean Absolute Error 4528.796193459509

# %%
plt.figure(figsize=(8,6))
sns.regplot(x=y_test,y=y_pred)
plt.title("Regression Plot",size=16)
plt.ylabel("Death cases",size=14)
plt.xlabel("total Confirmed cases",size=14)
plt.show()

# %% [markdown]
# ## Conclusion

# %%
Done the analysis of Covid-19 in india from january 2020 to august 2020.The covid case is first reported in kerala.Maharastra has the
maximum number of covid cases in india .West bengal is the most recovered state and maharastra has the highest number of deaths
in india.

# %% [markdown]
# ## Reference

# %%
www.kaggle.com

# %%
www.encyclopedia.com
